# %% [markdown]
# # 2. Customer Segmentation by Spending Tier
# **Goal:** Group customers into tiers (High, Medium, Low) based on their total
# spend — how many customers fall into each tier?
#
# **Fact:** InvoiceLine (LineAmount)
# **Dimensions:** Customer
# **Extra:** Define spend thresholds (e.g., High > $50, Medium $20–50,
# Low < $20).

# %% [markdown]
# # Cleaning the fact and dimension tables
#
# - Create temp tables in order to see cleaning process

# %% [markdown]
# Path:
# - In order to join the fact and dimension table, the query must traverse through InvoiceLine -> Invoice -> Customers.

# %% [markdown]
# # Customer Table Data Cleaning

# %%
# %sql
SELECT *
FROM customer
